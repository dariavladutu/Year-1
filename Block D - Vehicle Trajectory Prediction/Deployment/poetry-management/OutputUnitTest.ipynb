# %% [markdown]
# # python UnitTest.py
# 2024-06-18 13:47:29.834743: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# .....2024-06-18 13:49:10,574 - INFO - Selecting relevant features and target variable.
# 2024-06-18 13:49:10,601 - INFO - Splitting the dataset into training and testing sets.
# 2024-06-18 13:49:10,803 - INFO - Standardizing the features.
# 2024-06-18 13:49:10,884 - INFO - Building the DNN model.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-06-18 13:49:13.879676: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-06-18 13:49:13.880089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-06-18 13:49:13.880424: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-06-18 13:49:13.880805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 37885 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6
# 2024-06-18 13:49:13.881068: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-06-18 13:49:13.881452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 42994 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:c1:00.0, compute capability: 8.6
# 2024-06-18 13:49:13.881694: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-06-18 13:49:13.882077: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 42411 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:e1:00.0, compute capability: 8.6
# 2024-06-18 13:49:13,978 - INFO - Compiling the model.
# 2024-06-18 13:49:13,985 - INFO - Training the model.
# 2024-06-18 13:49:13,985 - INFO - Evaluating the model.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718718555.125251 3149466 service.cc:145] XLA service 0x7fda94007ff0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1718718555.125304 3149466 service.cc:153]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# I0000 00:00:1718718555.125313 3149466 service.cc:153]   StreamExecutor device (1): NVIDIA RTX A6000, Compute Capability 8.6
# I0000 00:00:1718718555.125320 3149466 service.cc:153]   StreamExecutor device (2): NVIDIA RTX A6000, Compute Capability 8.6
# I0000 00:00:1718718555.125327 3149466 service.cc:153]   StreamExecutor device (3): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-06-18 13:49:15.142510: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-18 13:49:15.173548: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:470] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2024-06-18 13:49:15.173650: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:474] Memory usage: 786432 bytes free, 51033931776 bytes total.
# 2024-06-18 13:49:15.197104: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:470] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2024-06-18 13:49:15.197159: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:474] Memory usage: 786432 bytes free, 51033931776 bytes total.
# 2024-06-18 13:49:15.238431: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at xla_ops.cc:580 : FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.
# 2024-06-18 13:49:15.238477: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.
#          [[{{node StatefulPartitionedCall}}]]
# 2024-06-18 13:49:15,240 - ERROR - An error occurred: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/home/y1d/2023-24d-fai1-adsai-teamwork-t18/Deployment/poetry-management/UnitTest.py", line 111, in <module>
#
#   File "/usr/lib/python3.11/unittest/main.py", line 102, in __init__
#
#   File "/usr/lib/python3.11/unittest/main.py", line 274, in runTests
#
#   File "/usr/lib/python3.11/unittest/runner.py", line 217, in run
#
#   File "/usr/lib/python3.11/unittest/suite.py", line 84, in __call__
#
#   File "/usr/lib/python3.11/unittest/suite.py", line 122, in run
#
#   File "/usr/lib/python3.11/unittest/suite.py", line 84, in __call__
#
#   File "/usr/lib/python3.11/unittest/suite.py", line 122, in run
#
#   File "/usr/lib/python3.11/unittest/case.py", line 678, in __call__
#
#   File "/usr/lib/python3.11/unittest/case.py", line 623, in run
#
#   File "/usr/lib/python3.11/unittest/case.py", line 579, in _callTestMethod
#
#   File "/usr/lib/python3.11/unittest/mock.py", line 1359, in patched
#
#   File "/home/y1d/2023-24d-fai1-adsai-teamwork-t18/Deployment/poetry-management/UnitTest.py", line 107, in test_train_dnn_model
#
#   File "/home/y1d/2023-24d-fai1-adsai-teamwork-t18/Deployment/poetry-management/main_script.py", line 72, in train_dnn_model
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py", line 118, in error_handler
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 435, in evaluate
#
#   File "/usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py", line 165, in one_step_on_iterator
#
# DNN library initialization failed. Look at the errors above for more details.
#          [[{{node StatefulPartitionedCall}}]] [Op:__inference_one_step_on_iterator_491]
# .
# ----------------------------------------------------------------------
# Ran 6 tests in 103.192s
#
# OK
