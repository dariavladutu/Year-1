# %% [markdown]
# # poetry install
# Updating dependencies
# Resolving dependencies... (6.4s)
#
# Package operations: 93 installs, 1 update, 0 removals
#
#   - Installing mdurl (0.1.2)
#   - Installing numpy (1.26.4)
#   - Installing six (1.16.0)
#   - Installing asttokens (2.4.1)
#   - Installing contourpy (1.2.1)
#   - Installing cycler (0.12.1)
#   - Installing executing (2.0.1)
#   - Installing fonttools (4.53.0)
#   - Installing joblib (1.4.2)
#   - Installing kiwisolver (1.4.5)
#   - Installing markdown-it-py (3.0.0)
#   - Installing markupsafe (2.1.5)
#   - Installing packaging (24.1)
#   - Installing parso (0.8.4)
#   - Installing pillow (10.3.0)
#   - Installing platformdirs (4.2.2)
#   - Installing ptyprocess (0.7.0)
#   - Installing pure-eval (0.2.2)
#   - Installing pygments (2.18.0)
#   - Installing pyparsing (3.1.2)
#   - Installing python-dateutil (2.9.0.post0)
#   - Installing pytz (2024.1)
#   - Installing scipy (1.13.1)
#   - Installing threadpoolctl (3.5.0)
#   - Installing traitlets (5.14.3)
#   - Installing typing-extensions (4.12.2)
#   - Installing tzdata (2024.1)
#   - Installing wcwidth (0.2.13)
#   - Installing absl-py (2.1.0)
#   - Installing certifi (2024.6.2)
#   - Installing charset-normalizer (3.3.2)
#   - Installing decorator (5.1.1)
#   - Installing grpcio (1.64.1)
#   - Installing h5py (3.11.0)
#   - Installing idna (3.7)
#   - Installing jedi (0.19.1)
#   - Installing jupyter-core (5.7.2)
#   - Installing markdown (3.6)
#   - Installing matplotlib (3.9.0)
#   - Installing matplotlib-inline (0.1.7)
#   - Installing ml-dtypes (0.3.2)
#   - Installing namex (0.0.8)
#   - Installing optree (0.11.0)
#   - Installing pandas (2.2.2)
#   - Installing pexpect (4.9.0)
#   - Installing prompt-toolkit (3.0.47)
#   - Installing protobuf (4.25.3)
#   - Installing pyzmq (26.0.3)
#   - Installing rich (13.7.1)
#   - Installing scikit-learn (1.5.0)
#   - Updating setuptools (69.5.1 -> 70.0.0)
#   - Installing stack-data (0.6.3)
#   - Installing tensorboard-data-server (0.7.2)
#   - Installing tornado (6.4.1)
#   - Installing urllib3 (2.2.2)
#   - Installing werkzeug (3.0.3)
#   - Installing wheel (0.43.0)
#   - Installing astunparse (1.6.3)
#   - Installing click (8.1.7)
#   - Installing comm (0.2.2)
#   - Installing debugpy (1.8.1)
#   - Installing flatbuffers (24.3.25)
#   - Installing gast (0.5.4)
#   - Installing google-pasta (0.2.0)
#   - Installing imbalanced-learn (0.12.3)
#   - Installing ipython (8.25.0)
#   - Installing jupyter-client (8.6.2)
#   - Installing keras (3.3.3)
#   - Installing libclang (18.1.1)
#   - Installing mccabe (0.7.0)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nest-asyncio (1.6.0)
#   - Installing opt-einsum (3.3.0)
#   - Installing pathspec (0.12.1)
#   - Installing patsy (0.5.6)
#   - Installing psutil (5.9.8)
#   - Installing pycodestyle (2.12.0)
#   - Installing pyflakes (3.2.0)
#   - Installing requests (2.32.3)
#   - Installing seaborn (0.13.2)
#   - Installing tensorboard (2.16.2)
#   - Installing tensorflow-io-gcs-filesystem (0.37.0)
#   - Installing termcolor (2.4.0)
#   - Installing wrapt (1.16.0)
#   - Installing black (24.4.2)
#   - Installing flake8 (7.1.0)
#   - Installing imblearn (0.0)
#   - Installing ipykernel (6.29.4)
#   - Installing isort (5.13.2)
#   - Installing missingno (0.5.2)
#   - Installing psycopg2-binary (2.9.9)
#   - Installing statsmodels (0.14.2)
#   - Installing tensorflow (2.16.1): Installing...
#   - Installing tensorflow (2.16.1)
#   - Installing xgboost (2.0.3)
#
# Writing lock file
#
# Installing the current project: block-d (0.1.0)
# Warning: The current project could not be installed: [Errno 2] No such file or directory: '/home/y1d/2023-24d-fai1-adsai-teamwork-t18/Deployment/poetry-management/README.md'
# If you do not want to install the current project use --no-root.
# If you want to use Poetry only for dependency management but not for packaging, you can disable package mode by setting package-mode = false in your pyproject.toml file.
# In a future version of Poetry this warning will become an error!
#
# # poetry show
#
# absl-py                      2.1.0       Abseil Python Common Libraries, se...
#
# asttokens                    2.4.1       Annotate AST trees with source cod...
#
# astunparse                   1.6.3       An AST unparser for Python
#
# black                        24.4.2      The uncompromising code formatter.
#
# certifi                      2024.6.2    Python package for providing Mozil...
#
# charset-normalizer           3.3.2       The Real First Universal Charset D...
#
# click                        8.1.7       Composable command line interface ...
#
# comm                         0.2.2       Jupyter Python Comm implementation...
#
# contourpy                    1.2.1       Python library for calculating con...
#
# cycler                       0.12.1      Composable style cycles
#
# debugpy                      1.8.1       An implementation of the Debug Ada...
#
# decorator                    5.1.1       Decorators for Humans
#
# executing                    2.0.1       Get the currently executing AST no...
#
# flake8                       7.1.0       the modular source code checker: p...
#
# flatbuffers                  24.3.25     The FlatBuffers serialization form...
#
# fonttools                    4.53.0      Tools to manipulate font files
#
# gast                         0.5.4       Python AST that abstracts the unde...
#
# google-pasta                 0.2.0       pasta is an AST-based Python refac...
#
# grpcio                       1.64.1      HTTP/2-based RPC framework
#
# h5py                         3.11.0      Read and write HDF5 files from Python
#
# idna                         3.7         Internationalized Domain Names in ...
#
# imbalanced-learn             0.12.3      Toolbox for imbalanced dataset in ...
#
# imblearn                     0.0         Toolbox for imbalanced dataset in ...
#
# ipykernel                    6.29.4      IPython Kernel for Jupyter
#
# ipython                      8.25.0      IPython: Productive Interactive Co...
#
# isort                        5.13.2      A Python utility / library to sort...
#
# jedi                         0.19.1      An autocompletion tool for Python ...
#
# joblib                       1.4.2       Lightweight pipelining with Python...
#
# jupyter-client               8.6.2       Jupyter protocol implementation an...
#
# jupyter-core                 5.7.2       Jupyter core package. A base packa...
#
# keras                        3.3.3       Multi-backend Keras.
#
# kiwisolver                   1.4.5       A fast implementation of the Casso...
#
# libclang                     18.1.1      Clang Python Bindings, mirrored fr...
#
# markdown                     3.6         Python implementation of John Grub...
#
# markdown-it-py               3.0.0       Python port of markdown-it. Markdo...
#
# markupsafe                   2.1.5       Safely add untrusted strings to HT...
#
# matplotlib                   3.9.0       Python plotting package
#
# matplotlib-inline            0.1.7       Inline Matplotlib backend for Jupyter
#
# mccabe                       0.7.0       McCabe checker, plugin for flake8
#
# mdurl                        0.1.2       Markdown URL utilities
#
# missingno                    0.5.2       Missing data visualization module ...
#
# ml-dtypes                    0.3.2
#
# mypy-extensions              1.0.0       Type system extensions for program...
#
# namex                        0.0.8       A simple utility to separate the i...
#
# nest-asyncio                 1.6.0       Patch asyncio to allow nested even...
#
# numpy                        1.26.4      Fundamental package for array comp...
#
# opt-einsum                   3.3.0       Optimizing numpys einsum function
#
# optree                       0.11.0      Optimized PyTree Utilities.
#
# packaging                    24.1        Core utilities for Python packages
#
# pandas                       2.2.2       Powerful data structures for data ...
#
# parso                        0.8.4       A Python Parser
#
# pathspec                     0.12.1      Utility library for gitignore styl...
#
# patsy                        0.5.6       A Python package for describing st...
#
# pexpect                      4.9.0       Pexpect allows easy control of int...
#
# pillow                       10.3.0      Python Imaging Library (Fork)
#
# platformdirs                 4.2.2       A small Python package for determi...
#
# prompt-toolkit               3.0.47      Library for building powerful inte...
#
# protobuf                     4.25.3
#
# psutil                       5.9.8       Cross-platform lib for process and...
#
# psycopg2-binary              2.9.9       psycopg2 - Python-PostgreSQL Datab...
#
# ptyprocess                   0.7.0       Run a subprocess in a pseudo terminal
#
# pure-eval                    0.2.2       Safely evaluate AST nodes without ...
#
# pycodestyle                  2.12.0      Python style guide checker
#
# pyflakes                     3.2.0       passive checker of Python programs
#
# pygments                     2.18.0      Pygments is a syntax highlighting ...
#
# pyparsing                    3.1.2       pyparsing module - Classes and met...
#
# python-dateutil              2.9.0.post0 Extensions to the standard Python ...
#
# pytz                         2024.1      World timezone definitions, modern...
#
# pyzmq                        26.0.3      Python bindings for 0MQ
#
# requests                     2.32.3      Python HTTP for Humans.
#
# rich                         13.7.1      Render rich text, tables, progress...
#
# scikit-learn                 1.5.0       A set of python modules for machin...
#
# scipy                        1.13.1      Fundamental algorithms for scienti...
#
# seaborn                      0.13.2      Statistical data visualization
#
# setuptools                   70.0.0      Easily download, build, install, u...
#
# six                          1.16.0      Python 2 and 3 compatibility utili...
#
# stack-data                   0.6.3       Extract data from python stack fra...
#
# statsmodels                  0.14.2      Statistical computations and model...
#
# tensorboard                  2.16.2      TensorBoard lets you watch Tensors...
#
# tensorboard-data-server      0.7.2       Fast data loading for TensorBoard
#
# tensorflow                   2.16.1      TensorFlow is an open source machi...
#
# tensorflow-io-gcs-filesystem 0.37.0      TensorFlow IO
#
# termcolor                    2.4.0       ANSI color formatting for output i...
#
# threadpoolctl                3.5.0       threadpoolctl
#
# tornado                      6.4.1       Tornado is a Python web framework ...
#
# traitlets                    5.14.3      Traitlets Python configuration system
#
# typing-extensions            4.12.2      Backported and Experimental Type H...
#
# tzdata                       2024.1      Provider of IANA time zone data
#
# urllib3                      2.2.2       HTTP library with thread-safe conn...
#
# wcwidth                      0.2.13      Measures the displayed width of un...
#
# werkzeug                     3.0.3       The comprehensive WSGI web applica...
#
# wheel                        0.43.0      A built-package format for Python
#
# wrapt                        1.16.0      Module for decorators, wrappers an...
#
# xgboost                      2.0.3       XGBoost Python Package

# %% [markdown]
# ---

# %% [markdown]
# poetry run python -m ipykernel install --user --name PoetryEnvironment --display-name "Poetry Environment"
#
# Installed kernelspec PoetryEnvironment in /root/.local/share/jupyter/kernels/poetryenvironment
